# %%
import pandas as pd

df_employees = pd.read_csv ('../Project-Anaconda/employees.csv')
df_system_access = pd.read_csv ('../Project-Anaconda/system_access.csv') 
df_employees.set_index('employee_number', inplace=False)
df_employees = df_employees.set_index('last_name')
df = df_employees.join(df_system_access, how='left')
df.head(25)
# Out:
#             employee_number first_name                               email  \
# Abbate            EMP003291    Gweneth      gweneth.abbate@consultants.com
# Abbyss            EMP009217     Arthur       arthur.abbyss@consultants.com
# Abdee             EMP005929   Beatrice      beatrice.abdee@consultants.com
# Abels             EMP020096      Dyane         dyane.abels@consultants.com
# Aberdalgy         EMP011546    Christy   christy.aberdalgy@consultants.com
# Abramowitch       EMP011672      Tades   tades.abramowitch@consultants.com
# Adamiec           EMP011305  Hyacintha   hyacintha.adamiec@consultants.com
# Addington         EMP013312       Audi      audi.addington@consultants.com
# Adenot            EMP017349      Rhett        rhett.adenot@consultants.com
# Adkin             EMP017122   Prentiss      prentiss.adkin@consultants.com
# Agius             EMP010693     Dahlia        dahlia.agius@consultants.com
# Aingell           EMP009261    Carlota     carlota.aingell@consultants.com
# Ainscow           EMP009903      Amber       amber.ainscow@consultants.com
# Aird              EMP005889      Fanni          fanni.aird@consultants.com
# Akast             EMP008977     Carson        carson.akast@consultants.com
# Akitt             EMP017568      Ester         ester.akitt@consultants.com
# Alban             EMP021215      Lilas         lilas.alban@consultants.com
# Aldam             EMP021814      Tymon         tymon.aldam@consultants.com
# Aldcorn           EMP017902     Sherry      sherry.aldcorn@consultants.com
# Alders            EMP016669     Vaclav       vaclav.alders@consultants.com
# Aldin             EMP003287      Gayla         gayla.aldin@consultants.com
# Allaway           EMP006873        Pat         pat.allaway@consultants.com
# Amery             EMP008258      Meggy         meggy.amery@consultants.com
# Amsberger         EMP015682   Eleanora  eleanora.amsberger@consultants.com
# Andrewartha       EMP022867     Hilton  hilton.andrewartha@consultants.com
#
#                          title  id access_level
# Abbate         Account Manager NaN          NaN
# Abbyss         Account Manager NaN          NaN
# Abdee          Sales Assistant NaN          NaN
# Abels          Sales Assistant NaN          NaN
# Aberdalgy      Sales Assistant NaN          NaN
# Abramowitch    Account Manager NaN          NaN
# Adamiec      Director of Sales NaN          NaN
# Addington      Sales Assistant NaN          NaN
# Adenot         Account Manager NaN          NaN
# Adkin          Sales Assistant NaN          NaN
# Agius          Account Manager NaN          NaN
# Aingell        Sales Assistant NaN          NaN
# Ainscow        Sales Assistant NaN          NaN
# Aird         Director of Sales NaN          NaN
# Akast          Account Manager NaN          NaN
# Akitt        Director of Sales NaN          NaN
# Alban        Director of Sales NaN          NaN
# Aldam          Sales Assistant NaN          NaN
# Aldcorn      Director of Sales NaN          NaN
# Alders       Director of Sales NaN          NaN
# Aldin          Sales Assistant NaN          NaN
# Allaway        Sales Assistant NaN          NaN
# Amery          Account Manager NaN          NaN
# Amsberger      Sales Assistant NaN          NaN
# Andrewartha    Account Manager NaN          NaN
